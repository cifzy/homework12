# %% [markdown]
# <font face="times new roman" size="3" color="black">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="black"> Отчет по лабораторной работе №12 </center>
# <center>по дисциплине </center>
# <center><b>«Информационные технологии и программирование»</b></center>
# <center>на тему</center>
# <center><b>«GIT»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Выполнил: Карпов Д.С. </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black">       БИК2302 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Карпов Дмитрий Сергеевич</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Ассистент кафедры ТиЗВ Федоров Владимир Дмитриевич </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="black"> Москва, 2023 г. </p>
#
#   <hr>

# %% [markdown]
# ##Содержание

# %% [markdown]
# <a href = '#Задание'>1. Задание </a>
#
# <a href = '#Постановка_задач'>2. Постановка задач </a>
#
# <a href = '#Цель_работы'>3. Цель работы </a>
#
# <a href = '#Ход_работы'>4. Ход работы </a>
#
# <a href = '#Результат_выполнения_работы'>5. Результат выполнения работы </a>

# %% [markdown]
# #Задание
# <a name = 'Задание'>

# %% [markdown]
# Научиться работать с git и github.

# %% [markdown]
# #Постановка Задач
# <a name = 'Постановка_задач'>

# %% [markdown]
# 1. Установить GIT.
# 2. Создать локальный репозиторий.
# 3. Создать файл отчета по выполнению практической работы и поместить его в репозиторий.
# 4. Создайте ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.
# 5. Зарегистрироваться на github, создаем проект «homework IIT», залить содержимое из локального репозитория в проект на githab.
# 6. Разместить на github ранее созданный статический сайт.

# %% [markdown]
# #Цель работы
# <a name = 'Цель_работы'>

# %% [markdown]
# Загрузить сайт на github.

# %% [markdown]
# # Ход работы
# <a name = 'Ход_работы'>

# %% [markdown]
# 1. Скачаем GIT.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. После установки запустим GIT Bash и напишем команду для определения корневой папки и установки локального репозитория. $cd C:/project
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Скачаем данный файл-отчёт с описанными раннее действиями и добавим его с помощью команды в репозиторий.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Фиксируем в отчёте все проделанные ранее действия и создаём версию отчёта в git. И после проверяем обновилась ли версия отчёта.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Добавили коммит и создали новую ветку
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Загружаем отчёт в новую ветку с помощью команд git add. Делаем изменения в отчёте и проверяем статус командой git status.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. Переключаемся обратно в основную ветку и снова загружаем отчёт.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7. Регистрируемся на github и создаём проект homework IIT и загружаем в него все файлы.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8. Создаём новый репозиторий и загружаем туда свой статический сайт.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Результат выполнения работы
# <a name = 'Результат_выполнения_работы'>

# %% [markdown]
# Я познакомился с основами git и github и смог выполнить все требующиеся задания. https://github.com/cifzy/1
